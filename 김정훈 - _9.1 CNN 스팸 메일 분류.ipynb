# %% [markdown]
# ## CNN 스팸 메일 분류

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# * https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv

# %%
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv', filename='spam.csv')
data =pd.read_csv('spam.csv', encoding='latin-1')
len(data)
# Out:
# 5572

# %%
data[:10]
# Out:
#      v1                                                 v2 Unnamed: 4
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6   ham  Even my brother is not like to speak with me. ...        NaN
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8  spam  WINNER!! As a valued network customer you have...        NaN
# 9  spam  Had your mobile 11 months or more? U R entitle...        NaN

# %%
del data['Unnamed: 2']
del data['Unnamed: 3']
del data['Unnamed: 4']

data['v1'] = data['v1'].replace(['ham', 'spam'], [0, 1])
data[:10]
# Out:
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...
# 5   1  FreeMsg Hey there darling it's been 3 week's n...
# 6   0  Even my brother is not like to speak with me. ...
# 7   0  As per your request 'Melle Melle (Oru Minnamin...
# 8   1  WINNER!! As a valued network customer you have...
# 9   1  Had your mobile 11 months or more? U R entitle...

# %%
data.drop_duplicates(subset=['v2'], inplace=True)
len(data)
# Out:
# 5169

# %%
data['v1'].value_counts().plot(kind='bar')

# %%
X_data = data['v2']
y_data = data['v1']

# %%
vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(X_data)
sequences = tokenizer.texts_to_sequences(X_data)

# %%
sequences[:5]
# Out:
# [[47, 433, 780, 705, 662, 64, 8, 94, 121, 434, 142, 68, 57, 137],
#  [49, 306, 435, 6],
#  [53,
#   537,
#   8,
#   20,
#   4,
#   934,
#   2,
#   220,
#   706,
#   267,
#   70,
#   2,
#   2,
#   359,
#   537,
#   604,
#   82,
#   436,
#   185,
#   707,
#   437],
#  [6, 226, 152, 23, 347, 6, 138, 145, 56, 152],
#  [935, 1, 97, 96, 69, 453, 2, 877, 69, 198, 105, 438]]

# %%
X_data = sequences
print('메일 최대 길이: {}'.format(max(len(l) for l in X_data)))
print("메일 평균 길이: {}".format(sum(map(len, X_data))/len(X_data)))
# Out:
# 메일 최대 길이: 172
# 메일 평균 길이: 12.566840781582512

# %%
plt.hist([len(s) for s in X_data], bins=50)
plt.xlabel('Length of Samples')
plt.ylabel('Number of Samples')
plt.show()

# %%
max_len = 60
data = pad_sequences(X_data, maxlen=max_len)
print(data.shape)
# Out:
# (5169, 60)

# %%
n_train = int(len(sequences) * 0.8)
n_test = int(len(sequences) - n_train)

print(n_train)
print(n_test)
# Out:
# 4135
# 1034

# %%
X_train = data[:n_train]
y_train = np.array(y_data[:n_train])

X_test = data[n_train:]
y_test = np.array(y_data[n_train:])

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4135, 60)
# (4135,)
# (1034, 60)
# (1034,)

# %% [markdown]
# ### 모델 구성

# %%
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Embedding, Dropout, GlobalMaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32))
model.add(Dropout(.2))
model.add(Conv1D(32, 5, strides=1, padding='valid', activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation='relu'))
model.add(Dropout(.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 32)          32000
# _________________________________________________________________
# dropout_9 (Dropout)          (None, None, 32)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 32)          5152
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 39,329
# Trainable params: 39,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
es =EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(X_train, y_train,
          validation_split=.2,
          batch_size=64,
          epochs=10,
          callbacks=[es, mc])
# Out:
# Epoch 1/10
# 45/52 [========================>.....] - ETA: 0s - loss: 0.5168 - acc: 0.8410
# Epoch 00001: val_acc improved from -inf to 0.87304, saving model to best_model.h5
# 52/52 [==============================] - 0s 6ms/step - loss: 0.5025 - acc: 0.8446 - val_loss: 0.3779 - val_acc: 0.8730
# Epoch 2/10
# 45/52 [========================>.....] - ETA: 0s - loss: 0.3722 - acc: 0.8736
# Epoch 00002: val_acc did not improve from 0.87304
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3747 - acc: 0.8697 - val_loss: 0.3359 - val_acc: 0.8730
# Epoch 3/10
# 42/52 [=======================>......] - ETA: 0s - loss: 0.2196 - acc: 0.9089
# Epoch 00003: val_acc improved from 0.87304 to 0.98549, saving model to best_model.h5
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2010 - acc: 0.9190 - val_loss: 0.0813 - val_acc: 0.9855
# Epoch 4/10
# 52/52 [==============================] - ETA: 0s - loss: 0.0634 - acc: 0.9819
# Epoch 00004: val_acc did not improve from 0.98549
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0634 - acc: 0.9819 - val_loss: 0.0517 - val_acc: 0.9855
# Epoch 5/10
# 46/52 [=========================>....] - ETA: 0s - loss: 0.0365 - acc: 0.9912
# Epoch 00005: val_acc improved from 0.98549 to 0.98791, saving model to best_model.h5
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0395 - acc: 0.9900 - val_loss: 0.0453 - val_acc: 0.9879
# Epoch 6/10
# 45/52 [========================>.....] - ETA: 0s - loss: 0.0271 - acc: 0.9924
# Epoch 00006: val_acc did not improve from 0.98791
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0269 - acc: 0.9930 - val_loss: 0.0464 - val_acc: 0.9843
# Epoch 7/10
# 43/52 [=======================>......] - ETA: 0s - loss: 0.0195 - acc: 0.9945
# Epoch 00007: val_acc did not improve from 0.98791
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0202 - acc: 0.9946 - val_loss: 0.0467 - val_acc: 0.9831
# Epoch 8/10
# 43/52 [=======================>......] - ETA: 0s - loss: 0.0154 - acc: 0.9956
# Epoch 00008: val_acc did not improve from 0.98791
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0150 - acc: 0.9961 - val_loss: 0.0473 - val_acc: 0.9855
# Epoch 00008: early stopping

# %% [markdown]
# ### 시각화

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(1, len(loss)+ 1)

plt.plot(epochs, loss, 'b--', label='Training Loss')
plt.plot(epochs, val_loss, 'r--', label='Validation Loss')
plt.grid()
plt.legend()

plt.figure()
plt.plot(epochs, acc, 'b--', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r--', label='Validation Accuracy')
plt.grid()
plt.legend()

plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0629 - acc: 0.9807
# [0.06287180632352829, 0.9806576371192932]
